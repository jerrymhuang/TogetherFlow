# %% [markdown]
# # Togetherflow
# **Emergent agent motion dynamics in immersive rooms**
#
# In this notebook, we implement Togetherflow, a computational cognitive model that characterizes the motion pattern of human agents in immersive rooms.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from functools import partial

np.set_printoptions(suppress=True)

# %%
import tensorflow as tf
import bayesflow as bf
from bayesflow.simulation import Prior, Simulator, GenerativeModel

# %%
from initializations import initialize_agents, initialize_beacons
from simulations import motion_simulation

from priors import complete_pooling_prior

# %% [markdown]
# ## Initializations
#
# First, we need to initialize some agents and some beacons.

# %%
agent_positions, agent_rotations = initialize_agents()
beacon_positions = initialize_beacons()
agent_rotations.shape
# Out:
# (12, 1)

# %% [markdown]
# ## Influences
#
# There are 4 influence vectors to an agent:
# * **Positional influence** (individual): drift-diffusion process for agent displacement (locomotion);
# * **Rotational influence** (individual): drift-diffusion process for agent orientation (head movement);
# * **Cohesion influence** (collective): active particle dynamics for agent position following;
# * **Alignment influence** (collective): active particle dynamics for agent orientation following.
#
# The implementation of all influences can be found in the `influences` module. Implemented simulations based on the individual influences and their respective combinations based on their categories can be found in the `simulations` module. In addition, some basic diagnostics function to ensure the individual influences behave as intended can be found in the `diagnostics` module.

# %% [markdown]
# ## Final simulation
#
# Combining all influences yields the final simulation.

# %%
# At the room's maximum occupancy
sim = motion_simulation(num_agents=49, num_beacons=25)

# %%
simulator = Simulator(simulator_fun=partial(motion_simulation, timesteps=1001))

# %% [markdown]
# # Priors

# %%
param_names = [r"$w_a$", r"$r_a$", r"$v_a$"]

# %%
prior = Prior(prior_fun=complete_pooling_prior, param_names=param_names)

# %% [markdown]
# ## Checks

# %%
pp_checks = prior.plot_prior2d()

# %% [markdown]
# ## Generative model

# %%
model = GenerativeModel(
    prior=prior,
    simulator=simulator,
    simulator_is_batched=False,
    name="tflow"
)
# Out:
# INFO:root:Performing 2 pilot runs with the tflow model...
# INFO:root:Shape of parameter batch after 2 pilot simulations: (batch_size = 2, 3)
# INFO:root:Shape of simulation batch after 2 pilot simulations: (batch_size = 2, 1001, 12, 3)
# INFO:root:No optional prior non-batchable context provided.
# INFO:root:No optional prior batchable context provided.
# INFO:root:No optional simulation non-batchable context provided.
# INFO:root:No optional simulation batchable context provided.

# %%
import matplotlib.pyplot as plt

sim = model(5)
test_sim = sim['sim_data'][2]
plt.plot(test_sim[:,0,-1])

# %% [markdown]
# # Configurator

# %%
def configurator(input_dict: dict = None, transpose: bool = True):
    
    output_dict = {}
    output_dict['parameters'] = input_dict['prior_draws'].astype(np.float32)
    x = input_dict['sim_data'] / 10. 
    if transpose:
        x = np.transpose(x, (0, 2, 1, 3))
    output_dict['summary_conditions'] = x.astype(np.float32)
    return output_dict

# %% [markdown]
# # Neural Approximator

# %%
# This one generalizes over different numbers of agents
summary_net = bf.summary_networks.HierarchicalNetwork([
    tf.keras.layers.TimeDistributed(tf.keras.layers.LSTM(units=128)),
    bf.networks.SetTransformer(num_inducing_points=None, input_dim=128, summary_dim=64)
])

inference_net = bf.inference_networks.InvertibleNetwork(
    num_params=3, 
    num_coupling_layers=6,
    coupling_design="affine",
    coupling_settings={
        'kernel_regularizer': None,
        'dropout_prob': 0.0
    }
)

amortizer = bf.amortizers.AmortizedPosterior(
    summary_net=summary_net, 
    inference_net=inference_net
)

# %% [markdown]
# # Training

# %%
trainer = bf.trainers.Trainer(
    amortizer=amortizer,
    generative_model=model,
    configurator=configurator
)
# Out:
# INFO:root:Performing a consistency check with provided components...
# INFO:root:Done.

# %% [markdown]
# ### Training
#
# To make sure that the model is trainable.

# %%
losses = trainer.train_online(epochs=1, batch_size=32, iterations_per_epoch=500)
# Out:
# Training epoch 1:   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 losses = trainer.train_online(epochs=1, batch_size=32, iterations_per_epoch=500)
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\trainers.py:438, in Trainer.train_online(self, epochs, iterations_per_epoch, batch_size, save_checkpoint, optimizer, reuse_optimizer, early_stopping, use_autograph, validation_sims, **kwargs)
#     435 with tqdm(total=iterations_per_epoch, desc=f"Training epoch {ep}", mininterval=TQDM_MININTERVAL) as p_bar:
#     436     for it in range(1, iterations_per_epoch + 1):
#     437         # Perform one training step and obtain current loss value
# --> 438         loss = self._train_step(batch_size, update_step=_backprop_step, **kwargs)
#     440         # Store returned loss
#     441         self.loss_history.add_entry(ep, loss)
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\trainers.py:1225, in Trainer._train_step(self, batch_size, update_step, input_dict, **kwargs)
#    1200 """Performs forward inference -> configuration -> network -> loss pipeline.
#    1201
#    1202 Parameters
#    (...)
#    1221
#    1222 """
#    1224 if input_dict is None:
# -> 1225     input_dict = self._forward_inference(
#    1226         batch_size, **kwargs.pop("conf_args", {}), **kwargs.pop("model_args", {})
#    1227     )
#    1228 if self.simulation_memory is not None:
#    1229     self.simulation_memory.store(input_dict)
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\trainers.py:1259, in Trainer._forward_inference(self, n_sim, configure, **kwargs)
#    1257 if self.generative_model is None:
#    1258     raise SimulationError("No generative model specified. Only offline learning is available!")
# -> 1259 out_dict = self.generative_model(n_sim, **kwargs.pop("model_args", {}))
#    1260 if configure:
#    1261     out_dict = self.configurator(out_dict, **kwargs.pop("conf_args", {}))
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\simulation.py:773, in GenerativeModel.__call__(self, batch_size, **kwargs)
#     771 # Forward inference
#     772 prior_out = self.prior(batch_size, **kwargs.pop("prior_args", {}))
# --> 773 sim_out = self.simulator(prior_out["prior_draws"], **kwargs.pop("sim_args", {}))
#     775 # Prepare and fill placeholder dict
#     776 out_dict = {
#     777     DEFAULT_KEYS["prior_non_batchable_context"]: prior_out[DEFAULT_KEYS["non_batchable_context"]],
#     778     DEFAULT_KEYS["prior_batchable_context"]: prior_out[DEFAULT_KEYS["batchable_context"]],
#    (...)
#     782     DEFAULT_KEYS["sim_data"]: sim_out[DEFAULT_KEYS["sim_data"]],
#     783 }
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\simulation.py:598, in Simulator.__call__(self, params, *args, **kwargs)
#     596 if self.is_batched:
#     597     return self._simulate_batched(params, out_dict, *args, **kwargs)
# --> 598 return self._simulate_non_batched(params, out_dict, *args, **kwargs)
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\simulation.py:655, in Simulator._simulate_non_batched(self, params, out_dict, *args, **kwargs)
#     649 # No context type
#     650 if (
#     651     out_dict[DEFAULT_KEYS["batchable_context"]] is None
#     652     and out_dict[DEFAULT_KEYS["non_batchable_context"]] is None
#     653 ):
#     654     out_dict[DEFAULT_KEYS["sim_data"]] = np.array(
# --> 655         [self.simulator(non_batched_params[b], *args, **kwargs) for b in range(batch_size)]
#     656     )
#     658 # Only batchable context
#     659 elif out_dict["non_batchable_context"] is None:
#
# File ~\Documents\Native\Permanent\TogetherFlow\env\lib\site-packages\bayesflow\simulation.py:655, in <listcomp>(.0)
#     649 # No context type
#     650 if (
#     651     out_dict[DEFAULT_KEYS["batchable_context"]] is None
#     652     and out_dict[DEFAULT_KEYS["non_batchable_context"]] is None
#     653 ):
#     654     out_dict[DEFAULT_KEYS["sim_data"]] = np.array(
# --> 655         [self.simulator(non_batched_params[b], *args, **kwargs) for b in range(batch_size)]
#     656     )
#     658 # Only batchable context
#     659 elif out_dict["non_batchable_context"] is None:
#
# KeyboardInterrupt:

# %%
l = bf.diagnostics.plot_losses(train_losses=losses['train_losses'], val_losses=losses['val_losses'])
