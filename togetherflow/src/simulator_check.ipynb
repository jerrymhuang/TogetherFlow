# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
import jax
jax.devices()
# Out:
# [CudaDevice(id=0)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from togetherflow.src.initialization import initialize_beacons, initialize_agents

# %%
p, r = initialize_agents(num_agents=3)
b = initialize_beacons(num_beacons=2)

# %%
plt.scatter(x=p[:,0], y=p[:,1], color="r")
plt.scatter(x=b[:,0], y=b[:,1], color="b")

# %%
from togetherflow.src.simulator import TogetherFlowSimulator

# %%
simulator = TogetherFlowSimulator(num_agents=49, num_beacons=8, time_horizon=30., dt=0.1, gather=False)

# %%
samples = simulator.sample((1, ))

# %%
samples
# Out:
# {'w': array([[0.15311772]], dtype=float32),
#  'r': array([[4.96653]], dtype=float32),
#  'v': array([[0.40291166]], dtype=float32),
#  'positions': array([[[[ 3.10213852e+00,  4.00681496e-01],
#           [ 5.56854248e-01, -2.28941679e+00],
#           [ 7.59701729e-01, -4.70766592e+00],
#           ...,
#           [ 2.95342922e+00, -2.29026532e+00],
#           [ 3.27310848e+00,  7.19934106e-01],
#           [ 2.67379332e+00, -4.26689816e+00]],
#
#          [[ 3.07103352e+00,  3.75071789e-01],
#           [ 5.17522123e-01, -2.29815533e+00],
#           [ 7.27908547e-01, -4.68291574e+00],
#           ...,
#           [ 2.92252149e+00, -2.26441789e+00],
#           [ 3.23283584e+00,  7.18712469e-01],
#           [ 2.69740563e+00, -4.29954531e+00]],
#
#          [[ 3.03439684e+00,  3.58304806e-01],
#           [ 4.81719788e-01, -2.31663696e+00],
#           [ 6.90773371e-01, -4.66728382e+00],
#           ...,
#           [ 2.88626518e+00, -2.24684353e+00],
# ...

# %%
positions = samples["positions"].squeeze()
positions.shape
# Out:
# (300, 49, 2)

# %%
for i in range(49):
    sns.lineplot(x=positions[:100,i,0], y=positions[:100,i,1])
