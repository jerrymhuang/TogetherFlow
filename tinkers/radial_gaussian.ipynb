# %%
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    x = np.linspace(-5., 5., 1001)
    y = np.exp(-x*x/2)
    z = x + 3
    w = np.exp(-x*z/2)

    plt.figure()
    plt.plot(x, y)
